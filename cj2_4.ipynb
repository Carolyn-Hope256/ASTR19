# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
d = np.random.power(4,1000)
b = 100
plt.hist(d, b)
plt.xlabel("Bin Value")
plt.ylabel("Bin Size")
plt.savefig("cj2_4_fig.pdf", format='pdf', bbox_inches = 'tight')
